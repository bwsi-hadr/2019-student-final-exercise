# %% [markdown]
# <a href="https://colab.research.google.com/github/bwsi-hadr/2019-student-final-exercise/blob/master/Facility_Flooding_and_Set_Cover_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# need to specify location of some certificates for rasterio
# !export CURL_CA_BUNDLE=/etc/ssl/certs/ca-certificates.crt
# !sudo mkdir -p /etc/pki/tls/certs
# !sudo cp /etc/ssl/certs/ca-certificates.crt /etc/pki/tls/certs/ca-bundle.crt
try:
  import rasterio
  import rasterio.plot
  import rasterio.merge 
  import rasterio.mask
except:
  # !pip install rasterio
  import rasterio
  import rasterio.plot
  import rasterio.merge
  import rasterio.mask
  
try:
  import rasterstats as rs
except:
  # !pip install rasterstats  
  import rasterstats as rs
  
try:
  import pyproj
except:
  # !pip install pyproj
  import pyproj
  
import networkx as nx
try:
  import osmnx as ox
except:
  # osmnx depends on the system package libspatialindex
  # !apt install libspatialindex-dev
  # !pip install osmnx
  import osmnx as ox

try: 
  import geopandas as gpd
except: 
  # !pip install geopandas 
  import geopandas as gpd
  
try:
  import contextily as ctx 
except:
  # install dependencies for contextily
  # !apt install libproj-dev proj-data proj-bin
  # !apt install libgeos-dev
  # !pip install cython
  # !pip install cartopy
  # install contextily
  # !pip install contextily==1.0rc1 --no-use-pep517 --no-cache-dir
  import contextily as ctx
  
import fiona
from shapely.geometry import Point, LineString, Polygon
  
import gdal
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/'My Drive'/BWSI-Remote-Sensing/'Final_exercise'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/BWSI-Remote-Sensing/Final_exercise

# %%
# !ls game_grid_export
# Out:
# facilities	      flooding.prj	       game_grid_all_stats.dbf
# facilities_stats.csv  flooding.shp	       game_grid_all_stats.prj
# flooding.cpg	      flooding.shx	       game_grid_all_stats.shp
# flooding.dbf	      game_grid_all_stats.cpg  game_grid_all_stats.shx

# %%
grid = gpd.read_file('game_grid_export/game_grid_all_stats.shp').to_crs(epsg = 3857)
grid['centroid'] = grid['geometry'].centroid

# %%
to_m = lambda km: km * 1000

# %% [markdown]
# #Hospitals

# %%
hospital_grid = gpd.read_file('game_grid_export/facilities/hospitals.shp').to_crs(grid.crs)
hospital_grid.loc[hospital_grid.loc[:, 'BEDS'] >= 200, 'hos_radius (km)'] = 25
hospital_grid.loc[hospital_grid.loc[:, 'BEDS'] < 200, 'hos_radius (km)'] = 15

big_hospitals=hospital_grid[hospital_grid['BEDS']>=200].to_crs(grid.crs)
small_hospitals=hospital_grid[hospital_grid['BEDS']<200].to_crs(grid.crs)
hospitals_buffered = hospital_grid.copy().to_crs(grid.crs)
hospitals_buffered.loc[big_hospitals.index, 'geometry'] = hospitals_buffered.loc[big_hospitals.index,'geometry'].buffer(to_m(25))
hospitals_buffered.loc[small_hospitals.index, 'geometry'] = hospitals_buffered.loc[small_hospitals.index,'geometry'].buffer(to_m(15))

hosp_info = gpd.sjoin(grid, hospitals_buffered, how = 'inner', op = 'intersects')
hosp_infopop = hosp_info.groupby('NAME').sum()

alpha_hosp = hospitals_buffered.sort_values('NAME').set_index('NAME')
alpha_hosp['population'] = hosp_infopop['population'].values
alpha_orhosp = hospital_grid.sort_values('NAME').set_index('NAME')
alpha_hosp['centroid'] = alpha_orhosp['geometry'].values

alpha_hosp['population']
# Out:
# NAME
# ARBOUR FULLER HOSPITAL                                      216673
# ARBOUR HOSPITAL, THE                                        778984
# ARBOUR HUMAN RESOURCE INSTITUTE                             869992
# BAY RIDGE HOSPITAL BEVERLY                                  352378
# BETH ISRAEL DEACONESS HOSPITAL - NEEDHAM                    330194
# BETH ISRAEL DEACONESS HOSPITAL MILTON                       501945
# BETH ISRAEL DEACONESS HOSPITAL PLYMOUTH                      38508
# BETH ISRAEL DEACONESS MEDICAL CENTER - EAST CAMPUS         1208502
# BETH ISRAEL DEACONESS MEDICAL CENTER - WEST CAMPUS         1200722
# BOSTON MEDICAL CENTER - EAST NEWTON CAMPUS                 1216527
# BOSTON MEDICAL CENTER - MENINO CAMPUS                      1217093
# BOURNEWOOD HOSPITAL                                         712321
# BRIGHAM AND WOMEN'S HOSPITAL                               1204412
# CAMBRIDGE HEALTH ALLIANCE - CAMBRIDGE CAMPUS               1222459
# CAMBRIDGE HEALTH ALLIANCE - SOMERVILLE CAMPUS               840259
# CAMBRIDGE HEALTH ALLIANCE - WHIDDEN MEMORIAL CAMPUS         701449
# CAPE COD & ISLANDS COMMUNITY MENTAL HEALTH CENTER            37387
# CAPE COD HOSPITAL                                            75378
# CARITAS CARNEY HOSPITAL                                     607143
# CHILDREN'S HOSPITAL BOSTON                                 1201179
# CLINTON HOSPITAL                                             46784
# DANA-FARBER CANCER INSTITUTE                                867773
# DR JOHN C CORRIGAN MENTAL HEALTH CENTER                     119180
# DR SOLOMON CARTER FULLER MENTAL HEALTH CENTER               831214
# EDITH NOURSE ROGERS MEMORIAL VETERANS HOSPITAL              146433
# ELEANOR SLATER HOSPITAL                                     469423
# EMERSON HOSPITAL                                             78244
# EMMA PENDLETON BRADLEY HOSPITAL                             335609
# FALMOUTH HOSPITAL                                            25378
# FAULKNER HOSPITAL                                           727974
#                                                             ...
# RHODE ISLAND HOSPITAL                                       505346
# ROGER WILLIAMS MEDICAL CENTER                               337433
# SAINT ANNE'S HOSPITAL                                       123557
# SAINT JOSEPH HEALTH SERVICES OF RHODE ISLAND                503577
# SHRINERS' HOSPITAL FOR CHILDREN                             817256
# SIGNATURE HEALTHCARE BROCKTON HOSPITAL                      183559
# SOUTH COUNTY HOSPITAL                                        30931
# SOUTH SHORE HOSPITAL                                        532635
# SOUTHCOAST BEHAVIORAL HEALTH                                115103
# SOUTHCOAST HOSPITALS GROUP - CHARLTON MEMORIAL HOSPITAL     235822
# SOUTHCOAST HOSPITALS GROUP - ST. LUKE'S HOSPITAL            152247
# SOUTHCOAST HOSPITALS GROUP - TOBEY HOSPITAL CAMPUS           29251
# SPAULDING HOSPITAL FOR CONTINUING MED CARE CAMBRIDGE        866312
# SPAULDING REHABILITATION HOSPITAL                           758826
# SPAULDING REHABILITATION HOSPITAL CAPE COD                   37829
# ST. ELIZABETH'S MEDICAL CENTER                             1187782
# STURDY MEMORIAL HOSPITAL                                    130387
# TAUNTON STATE HOSPITAL                                       70371
# THE MIRIAM HOSPITAL                                         505783
# TUFTS MEDICAL CENTER                                       1220580
# VA BOSTON HEALTHCARE SYSTEM - JAMAICA PLAIN                1197581
# VA MEDICAL CENTER - BROCKTON DIVISION                       162274
# VA MEDICAL CENTER - PROVIDENCE                              337792
# VA MEDICAL CENTER - WEST ROXBURY DIVISION                   555405
# WALDEN BEHAVIORAL CARE, LLC                                 382943
# WESTWOOD/PEMBROKE HEALTH SYSTEM PEMBROKE                     67844
# WESTWOOD/PEMBROKE HEALTH SYSTEM WESTWOOD                    173915
# WHITTIER REHABILITATION HOSPITAL                             97627
# WINCHESTER HOSPITAL                                        1107665
# WOMEN AND INFANTS HOSPITAL OF RHODE ISLAND                  506912
# Name: population, Length: 106, dtype: int64

# %% [markdown]
# #EMS

# %%
EMS_grid = gpd.read_file('game_grid_export/facilities/EMS.shp').to_crs(grid.crs)
EMS_grid.loc[EMS_grid.loc[:, 'TOTAL_VEHI'] >= 5, 'EMS_radius (km)'] = 15
EMS_grid.loc[EMS_grid.loc[:, 'TOTAL_VEHI'] < 5, 'EMS_radius (km)'] = 10

big_EMS=EMS_grid[EMS_grid['TOTAL_VEHI']>=5].to_crs(grid.crs)
small_EMS=EMS_grid[EMS_grid['TOTAL_VEHI']<5].to_crs(grid.crs)
EMS_buffered = EMS_grid.copy().to_crs(grid.crs)
EMS_buffered.loc[big_EMS.index, 'geometry'] = EMS_buffered.loc[big_EMS.index,'geometry'].buffer(to_m(15))
EMS_buffered.loc[small_EMS.index, 'geometry'] = EMS_buffered.loc[small_EMS.index,'geometry'].buffer(to_m(10))

EMS_info = gpd.sjoin(grid, EMS_buffered, how = 'inner', op = 'intersects')
EMS_infopop = EMS_info.groupby('NAME').sum()

alpha_EMS = EMS_buffered.sort_values('NAME').set_index('NAME')
alpha_EMS = alpha_EMS.loc[~alpha_EMS.index.duplicated(keep='first')]
alpha_EMS.loc[EMS_infopop.index,'population'] = EMS_infopop['population'].values
alpha_EMS = alpha_EMS.dropna(subset=['population'])

alpha_EMS['population']
# Out:
# NAME
# ABINGTON FIRE DEPARTMENT STATION 1                               100719.0
# ABINGTON FIRE DEPARTMENT STATION 2                               183927.0
# ACTION AMBULANCE SERVICE - HEADQUARTERS                          204271.0
# ACTION AMBULANCE SERVICE - LYNN                                  177090.0
# ACTION AMBULANCE SERVICE - STONEHAM                              431782.0
# ACTION AMBULANCE SERVICE - SWAMPSCOTT                            192341.0
# ACTION AMBULANCE SERVICE - WAKEFIELD                             371726.0
# ACTION AMBULANCE SERVICE - WOBURN                                196171.0
# ACTON FIRE DEPARTMENT STATION 1                                   67473.0
# ACTON FIRE DEPARTMENT STATION 2                                   67614.0
# ACTON FIRE DEPARTMENT STATION 3                                   36307.0
# ACUSHNET EMERGENCY MEDICAL SERVICES                               82096.0
# ACUSHNET FIRE AND RESCUE STATION 1 - HEADQUARTERS                111806.0
# ACUSHNET FIRE AND RESCUE STATION 2                                79389.0
# ADVANCED MEDICAL TRANSPORT SERVICES LIMITED LIABILITY COMPANY    157578.0
# ALDEN MILLS POINT OF PINES FIRE STATION - TRAINING FACILITY      374033.0
# ALERT AMBULANCE INCORPORATED                                     177652.0
# ALERT AMBULANCE SERVICE INCORPORATED                              98182.0
# AMBCARE AMBULANCE SERVICE                                        101409.0
# AMERICAN MEDICAL RESPONSE - LYNN                                 337114.0
# AMERICAN MEDICAL RESPONSE OF MASSACHUSETTS INCORPORATED          185432.0
# ANGELS AMBULANCE HEADQUARTERS                                     98256.0
# ARLINGTON FIRE DEPARTMENT - HEADQUARTERS                         372755.0
# ARLINGTON FIRE DEPARTMENT - HIGHLAND STATION                     302811.0
# ARLINGTON FIRE DEPARTMENT - PARK CIRCLE STATION                  621716.0
# ARMSTRONG AMBULANCE SERVICE - BRIGHTON                           815362.0
# ARMSTRONG AMBULANCE SERVICE - BURLINGTON                         195804.0
# ARMSTRONG AMBULANCE SERVICE - CAMBRIDGE                          779368.0
# ARMSTRONG AMBULANCE SERVICE - HEADQUARTERS                       731864.0
# ARMSTRONG AMBULANCE SERVICE - LEXINGTON                           94078.0
#                                                                    ...
# WEST BARNSTABLE FIRE DEPARTMENT STATION 1                         27438.0
# WEST BRIDGEWATER FIRE DEPARTMENT                                  70210.0
# WEST GREENWICH COMMUNITY RESCUE                                   20415.0
# WEST WARWICK FIRE DEPARTMENT STATION 1 - HEADQUARTERS             78601.0
# WEST WARWICK FIRE DEPARTMENT STATION 2                           166687.0
# WESTBOROUGH FIRE DEPARTMENT                                       36640.0
# WESTERN COVENTRY FIRE DISTRICT STATION 2                          23203.0
# WESTON FIRE DEPARTMENT - CENTRAL STATION - HEADQUARTERS           90495.0
# WESTON FIRE DEPARTMENT STATION 2                                 252013.0
# WESTPORT FIRE DEPARTMENT STATION 1                                11673.0
# WESTPORT FIRE DEPARTMENT STATION 2                                62269.0
# WESTWOOD FIRE DEPARTMENT STATION 1 - HEADQUARTERS                 83857.0
# WESTWOOD FIRE DEPARTMENT STATION 2                                98943.0
# WHITMAN FIRE DEPARTMENT                                           88665.0
# WINCHESTER FIRE DEPARTMENT - HEADQUATERS                         253704.0
# WINCHESTER FIRE DEPARTMENT - WEST SIDE FIRE STATION              523252.0
# WINTHROP FIRE DEPARTMENT - HEADQUARTERS                          571560.0
# WINTHROP FIRE DEPARTMENT - SHIRLEY STREET STATION                144371.0
# WOBURN FIRE DEPARTMENT STATION 1 - HEADQUARTERS                  180114.0
# WOBURN FIRE DEPARTMENT STATION 2                                 260105.0
# WOBURN FIRE DEPARTMENT STATION 3                                 342434.0
# WOBURN FIRE DEPARTMENT STATION 4                                 411338.0
# WOBURN FIRE DEPARTMENT STATION 5                                 141624.0
# WOONSOCKET FIRE DEPARTMENT STATION 2                              92078.0
# WOONSOCKET FIRE DEPARTMENT STATION 3                              88968.0
# WRENTHAM FIRE DEPARTMENT STATION 1                                40094.0
# YARMOUTH FIRE DEPARTMENT STATION 1                                42034.0
# YARMOUTH FIRE DEPARTMENT STATION 2                                43494.0
# YARMOUTH FIRE DEPARTMENT STATION 3                                44960.0
# YAWGOO VALLEY SEARCH AND RESCUE                                   40661.0
# Name: population, Length: 585, dtype: float64

# %% [markdown]
# #Shelters

# %%
shelt_grid = gpd.read_file('game_grid_export/facilities/shelters.shp').to_crs(grid.crs)
shelt_grid['shelt_radius (km)'] = 3
shelt_buffered = shelt_grid.copy().to_crs(grid.crs)
shelt_buffered['geometry'] = shelt_buffered['geometry'].buffer(to_m(3))

shelt_info = gpd.sjoin(grid, shelt_buffered, how = 'inner', op = 'intersects')
shelt_infopop = shelt_info.groupby('NAME').sum()

alpha_shelt = shelt_buffered.sort_values('NAME').set_index('NAME')
alpha_shelt = alpha_shelt.loc[~alpha_shelt.index.duplicated(keep='first')]
alpha_shelt.loc[shelt_infopop.index,'population'] = shelt_infopop['population'].values
alpha_shelt = alpha_shelt.dropna(subset=['population'])

alpha_shelt['population']
# Out:
# NAME
# ABINGTON HIGH SCHOOL                                  9137.0
# ABINGTON SENIOR CENTER                               14835.0
# ACTON SENIOR CENTER                                   7603.0
# ADAMS MIDDLE SCHOOL                                  28433.0
# ADRIAN TINSLEY CENTER / BRIDGEWATER STATE COLLEGE    10563.0
# AGASSIZ COMMUNITY CENTER                             58607.0
# AHERN MIDDLE SCHOOL                                   7050.0
# AIKEN ELEMENTARY SCHOOL                              10480.0
# ALBERT F. FORD MIDDLE SCHOOL                          2726.0
# ALDEN ELEMENTARY SCHOOL                               3103.0
# ALFRED LIMA ELEMENTARY SCHOOL                        62965.0
# AMERICAL CIVIC CENTER                                20029.0
# ANGELO ELEMENTARY SCHOOL                             35089.0
# ANNA M. MCCABE SCHOOL                                 7414.0
# ANTHONY CARNEVALE JR. ELEMENTARY SCHOOL              48654.0
# AQUINNAH TOWN HALL                                     202.0
# ARLINGTON CATHOLIC HIGH SCHOOL                       46639.0
# ARLINGTON HIGH SCHOOL                                38426.0
# ARLINGTON LIBRARY                                    54136.0
# ARNONE COMMUNITY SCHOOL                              37055.0
# ASHLAND HIGH SCHOOL                                  14647.0
# ASHLAND MIDDLE SCHOOL                                 6044.0
# ASSAWOMPSET ELEMENTARY SCHOOL                         1682.0
# ATLANTIC UNION COLLEGE                                5210.0
# ATRIA BAY SPRING VILLAGE                              9784.0
# ATTLEBORO HIGH SCHOOL                                13578.0
# AUBURN LIBRARY                                       40374.0
# AUSTIN INTERMEDIATE SCHOOL                            1801.0
# AVON COUNCIL ON AGING                                14457.0
# AVON MIDDLE-HIGH SCHOOL                              13426.0
#                                                       ...
# WHITTIER SCHOOL                                      63134.0
# WICKFORD MIDDLE SCHOOL                                4283.0
# WILBUR AND MCMAHON SCHOOLS                             823.0
# WILFRID MANOR                                        38281.0
# WILLCUTT COMMONS SENIOR CENTER                        3939.0
# WILLIAM HALL LIBRARY                                 22463.0
# WILLIAMS INTERMEDIATE SCHOOL                         10487.0
# WILLIAMS MIDDLE SCHOOL                               73321.0
# WILSON ELEMENTARY SCHOOL                             20179.0
# WILSON MIDDLE SCHOOL                                 14370.0
# WINCHESTER HIGH SCHOOL                               15016.0
# WINMAN JUNIOR HIGH SCHOOL                            15453.0
# WINTER HILL COMMUNITY INNOVATION SCHOOL              81900.0
# WINTHROP HIGH SCHOOL                                 21395.0
# WITCHCRAFT HEIGHTS ELEMENTARY SCHOOL                 35593.0
# WIXON MIDDLE SCHOOL                                   4510.0
# WOBURN MEMORIAL HIGH SCHOOL                          22740.0
# WOBURN SENIOR CENTER                                 14280.0
# WOLLASTON ELEMENTARY SCHOOL                          42542.0
# WOOD ELEMENTARY SCHOOL                                5357.0
# WOODSDALE SCHOOL                                      9523.0
# WOODVILLE ELEMENTARY SCHOOL                          16942.0
# WOODWARD MEMORIAL SCHOOL                              3332.0
# WOONSOCKET LIBRARY                                   29276.0
# WOONSOCKET SENIOR CENTER                             30272.0
# WORCESTER COUNTY FOOD BANK, INC.                     13154.0
# WRENTHAM COUNCIL ON AGING                             3855.0
# WRENTHAM DEVELOPMENT CENTER                           5049.0
# YMCA OF CHELSEA                                      67872.0
# YOUNG ACHIEVERS SCIENCE AND MATH SCHOOL              48503.0
# Name: population, Length: 780, dtype: float64

# %% [markdown]
# #Fire Stations

# %%
fire_grid = gpd.read_file('game_grid_export/facilities/fire_stations.shp').to_crs(grid.crs)
fire_grid['fire_radius (km)'] = 15
fire_buffered = fire_grid.copy().to_crs(grid.crs)
fire_buffered['geometry'] = fire_buffered['geometry'].buffer(to_m(15))

fire_info = gpd.sjoin(grid, fire_buffered, how = 'inner', op = 'intersects')
fire_infopop = fire_info.groupby('NAME').sum()

alpha_fire = fire_buffered.sort_values('NAME').set_index('NAME')
alpha_fire = alpha_fire.loc[~alpha_fire.index.duplicated(keep='first')]
alpha_fire.loc[fire_infopop.index,'population'] = fire_infopop['population'].values
alpha_fire = alpha_fire.dropna(subset=['population'])

alpha_fire['population']
# Out:
# NAME
# ABINGTON FIRE DEPARTMENT STATION 1                             210174.0
# ABINGTON FIRE DEPARTMENT STATION 2                             183927.0
# ACTON FIRE DEPARTMENT STATION 1                                 67473.0
# ACTON FIRE DEPARTMENT STATION 2                                 67614.0
# ACTON FIRE DEPARTMENT STATION 3                                 66696.0
# ACUSHNET FIRE AND RESCUE STATION 1 - HEADQUARTERS              111806.0
# ACUSHNET FIRE AND RESCUE STATION 2                              79389.0
# ALBION FIRE DEPARTMENT                                         183429.0
# ALDEN MILLS POINT OF PINES FIRE STATION - TRAINING FACILITY    374033.0
# AQUINNAH FIRE DEPARTMENT                                          826.0
# ARLINGTON FIRE DEPARTMENT - HEADQUARTERS                       733870.0
# ARLINGTON FIRE DEPARTMENT - HIGHLAND STATION                   667193.0
# ARLINGTON FIRE DEPARTMENT - PARK CIRCLE STATION                621716.0
# ASHLAND FIRE DEPARTMENT STATION 1                              121555.0
# ASHLAND FIRE DEPARTMENT STATION 2 - HEADQUARTERS               119366.0
# ATTLEBORO FIRE AND RESCUE - SOUTH ATTLEBORO STATION            187306.0
# ATTLEBORO FIRE AND RESCUE - TWIN VILLAGE STATION               174883.0
# ATTLEBORO FIRE DEPARTMENT - BRIGGS CORNER STATION              121693.0
# ATTLEBORO FIRE DEPARTMENT - HEADQUARTERS                       137531.0
# AVON FIRE DEPARTMENT                                           210078.0
# BARNSTABLE HEADQUARTERS FIRE STATION BA-1                       45881.0
# BARRINGTON FIRE DEPARTMENT                                     203748.0
# BEDFORD FIRE DEPARTMENT                                        146537.0
# BELLINGHAM FIRE DEPARTMENT STATION 1                            98573.0
# BELLINGHAM FIRE DEPARTMENT STATION 2 - HEADQUARTERS            113929.0
# BELLINGHAM FIRE DEPARTMENT STATION 3                            90766.0
# BELMONT FIRE DEPARTMENT STATION 1 - HEADQUARTERS               689980.0
# BELMONT FIRE DEPARTMENT STATION 2                              701149.0
# BERKLEY FIRE DEPARTMENT STATION 1 - HEADQUARTERS                68615.0
# BERKLEY FIRE DEPARTMENT STATION 2                               58776.0
#                                                                  ...
# WESTON FIRE DEPARTMENT - CENTRAL STATION - HEADQUARTERS        238029.0
# WESTON FIRE DEPARTMENT STATION 2                               252013.0
# WESTPORT FIRE DEPARTMENT STATION 1                              30182.0
# WESTPORT FIRE DEPARTMENT STATION 2                             100525.0
# WESTWOOD FIRE DEPARTMENT STATION 1 - HEADQUARTERS              204627.0
# WESTWOOD FIRE DEPARTMENT STATION 2                             232036.0
# WEYMOUTH FIRE DEPARTMENT STATION 1                             199016.0
# WEYMOUTH FIRE DEPARTMENT STATION 2 - HEADQUARTERS              185307.0
# WEYMOUTH FIRE DEPARTMENT STATION 3                             199579.0
# WEYMOUTH FIRE DEPARTMENT STATION 5                             201877.0
# WHITMAN FIRE DEPARTMENT                                        164113.0
# WINCHESTER FIRE DEPARTMENT - HEADQUATERS                       546696.0
# WINCHESTER FIRE DEPARTMENT - WEST SIDE FIRE STATION            523252.0
# WINTHROP FIRE DEPARTMENT - HEADQUARTERS                        571560.0
# WINTHROP FIRE DEPARTMENT - SHIRLEY STREET STATION              487494.0
# WOBURN FIRE DEPARTMENT STATION 1 - HEADQUARTERS                434719.0
# WOBURN FIRE DEPARTMENT STATION 2                               260105.0
# WOBURN FIRE DEPARTMENT STATION 3                               342434.0
# WOBURN FIRE DEPARTMENT STATION 4                               411338.0
# WOBURN FIRE DEPARTMENT STATION 5                               377149.0
# WOONSOCKET FIRE DEPARTMENT STATION 1                            87664.0
# WOONSOCKET FIRE DEPARTMENT STATION 2                            92078.0
# WOONSOCKET FIRE DEPARTMENT STATION 3                            88968.0
# WOONSOCKET FIRE DEPARTMENT STATION 4                           101780.0
# WOONSOCKET FIRE DEPARTMENT STATION 6                            87911.0
# WRENTHAM FIRE DEPARTMENT STATION 1                              94608.0
# WRENTHAM FIRE DEPARTMENT STATION 2                             117022.0
# YARMOUTH FIRE DEPARTMENT STATION 1                              42034.0
# YARMOUTH FIRE DEPARTMENT STATION 2                              43494.0
# YARMOUTH FIRE DEPARTMENT STATION 3                              44960.0
# Name: population, Length: 612, dtype: float64

# %% [markdown]
# #Set Cover Application for Hospitals (untested)

# %%
large_hos_cost = 200
small_hos_cost = 100

cost_ref = {'small': small_hos_cost, 'big': large_hos_cost}

# %%
hosp_to_cells = {}
for i, row in hosp_info.iterrows():
  hosp_name = row["NAME"]
  size = 'small' if row['BEDS'] < 200 else 'big'
  if hosp_name not in hosp_to_cells:
    hosp_to_cells[(hosp_name, size)] = {i}
  else:
    hosp_to_cells[(hosp_name, size)].add(i)

# %%
freq_chart = [0 for _ in range(grid.shape[0])]
covered = set()
def calc_weight(subset, size):
  return sum(grid.loc[cell, 'population'] for cell in subset) / cost_ref[size]

def set_cover(budget, facdict): #TODO: add cost_ref
  to_ret = set()
  while budget > 0:
    max_hosp, max_subset = max(facdict.items(), key = lambda tup: \
                               calc_weight(tup[1], tup[0][1]))
    for cell in max_subset:
      freq_chart[cell] += 1
#       if freq_chart[cell] == 2:
#         done.add(cell)
    
    budget -= cost_ref[max_hosp[1]]
    to_ret.add(max_hosp)
    
    for key in hosp_squares:
      hosp_squares[key] -= max_subset
    del facdict[max_hosp]
    
  return to_ret

# %% [markdown]
# #Proximity-to-Flood Function

# %%
flooding = gpd.read_file('game_grid_export/flooding.shp')

# %%
#Outputs a list of facilities in the specified distance from the flood
def prox(mindist, maxdist, flood, fac):
  fac_grid = None
  if fac == 'hospital':
    fac_grid = hospital_grid
  elif fac == 'EMS':
    fac_grid = EMS_grid
  elif fac == 'shelter':
    fac_grid = shelt_grid
  elif fac == 'firestation':
    fac_grid = fire_grid
  else:
    return "no"
  
  l = []
  for i in range(len(fac_grid)):
    dist = fac_grid.loc[i, 'geometry'].distance(flood)
    if dist <= maxdist and dist >= mindist: #TODO: mindist <= dist <= maxdist check
      l.append(fac_grid.loc[i, 'NAME'])
  return l

# %%
from shapely.geometry import MultiPolygon
import shapely.ops as shap
#Creates a MultiPolygon using the flood shapely file and the buffer size in meters
def flcreate(fl, b, i): 
  flooding = fl.copy().to_crs(grid.crs)
  flooding['geometry'] = flooding['geometry'].buffer(b)
  if i == 0:
    flood = flooding['geometry'].unary_union
  else:
    l = [MultiPolygon([flooding.loc[i, 'geometry'], \
                       flooding.loc[i + 1, 'geometry']]).convex_hull \
         for i in range(len(flooding) - 1)]
    flood = shap.cascaded_union(MultiPolygon(l))
    
  return flood

# %%
#Outputs all information for a list of facility names
def prettyUnicorn(l, fac):
  alpha_fac = None
  if fac == 'hospital':
    alpha_fac = alpha_hosp
  elif fac == 'EMS':
    alpha_fac = alpha_EMS
  elif fac == 'shelter':
    alpha_fac = alpha_shelt
  elif fac == 'firestation':
    alpha_fac = alpha_fire
  else:
    return "no"
  return alpha_fac.loc[l]

# %%
#Everything you'll need
#minimum distance, maximum distance, flood shapely file, buffer size in meters,
#type of graph (0: unary_union, 1: cascaded_union), facility type ('hospital', 'EMS', 'shelter', 'firestation')
def magic(mindist, maxdist, floodshp, buffer, graph_type = 0, fac = 'hospital'):
  return prettyUnicorn(prox(mindist, maxdist, flcreate(flooding, buffer, graph_type), fac), fac)

# %%
#Example
magic(0, 1000, flooding, 500)
# Out:
#                                                     OBJECTID  ...                                          centroid
# NAME                                                          ...
# PROVIDENCE VA MEDICAL CENTER                            24.0  ...  POINT Z (-7951949.155586868 5135837.564535611 0)
# NAVAL HEALTH CLINIC NEW ENGLAND, NEWPORT                27.0  ...   POINT Z (-7939506.027807591 5086957.87205448 0)
# VA MEDICAL CENTER - PROVIDENCE                          28.0  ...  POINT Z (-7951901.833110882 5135867.763963762 0)
# MEMORIAL HOSPITAL OF RHODE ISLAND                       30.0  ...    POINT Z (-7945590.786097784 5141514.2622464 0)
# WOMEN AND INFANTS HOSPITAL OF RHODE ISLAND              32.0  ...    POINT Z (-7949569.8250032 5132691.749874027 0)
# RHODE ISLAND HOSPITAL                                   34.0  ...   POINT Z (-7949227.90673675 5132841.662859567 0)
# EMMA PENDLETON BRADLEY HOSPITAL                         35.0  ...  POINT Z (-7944568.200346095 5129939.701677736 0)
# HASBRO CHILDRENS HOSPITAL                               37.0  ...   POINT Z (-7949203.10357041 5132732.457129485 0)
# ROGER WILLIAMS MEDICAL CENTER                           39.0  ...   POINT Z (-7952151.19906801 5136271.097543607 0)
# NEWPORT HOSPITAL                                        40.0  ...  POINT Z (-7937753.063821082 5085948.438040949 0)
# SOUTH COUNTY HOSPITAL                                   41.0  ...  POINT Z (-7958944.077175442 5076135.110957523 0)
# DR JOHN C CORRIGAN MENTAL HEALTH CENTER                 61.0  ...  POINT Z (-7919904.706361935 5117262.615547662 0)
# CAPE COD & ISLANDS COMMUNITY MENTAL HEALTH CENTER       84.0  ...  POINT Z (-7859421.558232985 5114416.887640206 0)
# MARTHA'S VINEYARD HOSPITAL                             179.0  ...  POINT Z (-7856907.396309995 5080549.000211069 0)
# SOUTHCOAST HOSPITALS GROUP - ST. LUKE'S HOSPITAL       181.0  ...    POINT Z (-7896826.5657296 5105179.226333707 0)
# SOUTHCOAST HOSPITALS GROUP - CHARLTON MEMORIAL ...     183.0  ...  POINT Z (-7919936.492044975 5117547.883270329 0)
# SAINT ANNE'S HOSPITAL                                  184.0  ...  POINT Z (-7921906.846993644 5115043.060270294 0)
# CAPE COD HOSPITAL                                      189.0  ...  POINT Z (-7822743.444570526 5109201.015920504 0)
# SOUTHCOAST HOSPITALS GROUP - TOBEY HOSPITAL CAMPUS     255.0  ...  POINT Z (-7871890.999769659 5124514.136134185 0)
#
# [19 rows x 24 columns]
